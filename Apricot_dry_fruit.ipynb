# %%
# !nvidia-smi

# %%
from ultralytics import YOLO

# %% [markdown]
# # Install **YOLOv8** *italicized text*

# %%
model=YOLO('yolov8m.pt')
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 67.7MB/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# # Custom ***Training***

# %%
model.train(data="/content/drive/MyDrive/organic_product/data.yaml" , epochs=80)
# Out:
# New https://pypi.org/project/ultralytics/8.0.199 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.198 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer=YOLO("/content/runs/detect/train22/weights/best.pt")

# %%
infer.predict("/content/drive/MyDrive/organic_product/ppp.mp4", save =True,save_txt=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/428) /content/drive/MyDrive/organic_product/ppp.mp4: 640x640 2 Halmans, 37.1ms
# video 1/1 (2/428) /content/drive/MyDrive/organic_product/ppp.mp4: 640x640 2 Halmans, 37.2ms
# video 1/1 (3/428) /content/drive/MyDrive/organic_product/ppp.mp4: 640x640 2 Halmans, 37.0ms
# video 1/1 (4/428) /content/drive/MyDrive/organic_product/ppp.mp4: 640x640 2 Halmans, 36.6ms
# ...

# %%
infer.predict("/content/drive/MyDrive/organic_product/data/test/images", save =True,save_txt=True)
# Out:
# image 1/40 /content/drive/MyDrive/organic_product/data/test/images/1.jpg: 608x640 1 Halman, 212.6ms
# image 2/40 /content/drive/MyDrive/organic_product/data/test/images/10.jpg: 608x640 1 Halman, 36.4ms
# image 3/40 /content/drive/MyDrive/organic_product/data/test/images/101.jpg: 640x640 1 sulphur_ halman, 38.3ms
# image 4/40 /content/drive/MyDrive/organic_product/data/test/images/102.jpg: 640x640 1 sulphur_ halman, 37.1ms
# image 5/40 /content/drive/MyDrive/organic_product/data/test/images/103.jpg: 640x576 1 sulphur_ halman, 128.1ms
# image 6/40 /content/drive/MyDrive/organic_product/data/test/images/104.jpg: 640x608 1 sulphur_ halman, 121.9ms
# image 7/40 /content/drive/MyDrive/organic_product/data/test/images/105.jpg: 640x512 1 sulphur_ halman, 120.8ms
# image 8/40 /content/drive/MyDrive/organic_product/data/test/images/106.jpg: 640x608 1 sulphur_ halman, 37.8ms
# image 9/40 /content/drive/MyDrive/organic_product/data/test/images/107.jpg: 640x576 1 sulphur_ halman, 37.2ms
# ...

# %% [markdown]
# # ***confusion_matrix***

# %%
Image(filename='/content/runs/detect/train22/confusion_matrix.png', width=600)

# %%
Image(filename='/content/runs/detect/train22/results.png', width=600)

# %%
Image(filename='/content/runs/detect/train22/val_batch0_pred.jpg', width=600)

# %% [markdown]
# # ***Inference with Custom Model***

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source=data/test/images
# Out:
# 2023-10-07 11:48:11.772051: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-07 11:48:13.172056: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11127132 parameters, 0 gradients, 28.4 GFLOPs
# image 1/40 /content/drive/MyDrive/orginic_product/data/test/images/1.jpg: 224x224 1 Halman, 7.2ms
# image 2/40 /content/drive/MyDrive/orginic_product/data/test/images/10.jpg: 224x224 1 Halman, 7.2ms
# image 3/40 /content/drive/MyDrive/orginic_product/data/test/images/101.jpg: 224x224 1 sulphur_ halman, 7.3ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('runs/detect/predict/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/runs/detect/train/results.csv')

# %%
data
# Out:
#                       epoch           train/box_loss           train/cls_loss  \
# 0                         1                   1.7245                  3.97000
# 1                         2                   1.3574                  1.93730
# 2                         3                   1.3837                  1.37470
# 3                         4                   1.4687                  1.23460
# 4                         5                   1.4282                  1.24270
# 5                         6                   1.4344                  1.14370
# 6                         7                   1.4694                  1.08300
# 7                         8                   1.4117                  1.04050
# 8                         9                   1.4105                  1.04110
# 9                        10                   1.4334                  1.04090
# 10                       11                   1.3582                  0.92601
# ...
