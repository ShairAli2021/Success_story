# %%
# !nvidia-smi
# Out:
# Sun Nov 26 07:52:09 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics==8.0.20
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.2/261.2 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.7/251.7 kB 26.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 57.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %% [markdown]
# # Install **YOLOv8** *italicized text*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/project/FYP
# Out:
# /content/drive/MyDrive/project/FYP

# %%
# %cd /content/drive/MyDrive/project/FYP
model=YOLO('yolov8n.pt')
# Out:
# /content/drive/MyDrive/project/FYP

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# # Custom ***Training***

# %%
# %cd /content/drive/MyDrive/project/FYP
model.train(data="/content/drive/MyDrive/project/FYP/data.yaml" , epochs=100)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model=YOLO("/content/drive/MyDrive/project/FYP/runs/detect/train4/weights/best.pt")

# %%
model.predict("/content/drive/MyDrive/project/FYP/data/test/images", save =True,save_txt=True)
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
# Results saved to runs/detect/predict7
# 37 labels saved to runs/detect/predict7/labels
# [Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([0, 6])
#  dtype: torch.float32
#   + tensor([], device='cuda:0', size=(0, 6)),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[ 1.00000,  1.00000, 98.00000, 87.00000,  0.51588,  0.00000]], device='cuda:0'),
#  Ultralytics YOLO <class 'ultralytics.yolo.engine.results.Boxes'> masks
#  type: <class 'torch.Tensor'>
#  shape: torch.Size([1, 6])
#  dtype: torch.float32
#   + tensor([[  0.00000,   3.00000, 100.00000,  90.00000,   0.46684,   1.00000]], device='cuda:0'),
# ...

# %% [markdown]
# # ***confusion_matrix***

# %%
Image(filename='/content/drive/MyDrive/project/FYP/runs/detect/train4/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/project/FYP/runs/detect/train4/val_batch0_labels.jpg', width=600)

# %%
Image(filename='/content/drive/MyDrive/project/FYP/runs/detect/train3/val_batch0_pred.jpg', width=600)

# %%
Image(filename='//content/drive/MyDrive/project/FYP/runs/detect/train4/F1_curve.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/project/FYP/runs/detect/train4/R_curve.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/project/FYP/runs/detect/train4/P_curve.png', width=600)

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %% [markdown]
# # ***Validate Custom Model***

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/project/FYP/runs/detect/train4/weights/best.pt conf=0.50 source=/content/drive/MyDrive/project/FYP/data/test/images
# Out:
# 2023-11-25 11:29:32.543831: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-25 11:29:32.543903: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-25 11:29:32.543942: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-25 11:29:33.589986: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
# ...

# %% [markdown]
# # ***Inference with Custom Model***

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/project/FYP/runs/detect/train3/weights/best.pt"conf=0.25 source=/content/drive/MyDrive/project/FYP/data/test/images
# !yolo task=detect mode=predict model="/content/drive/MyDrive/project/FYP/runs/detect/train4/weights/best.pt" conf=0.25 source=/content/drive/MyDrive/project/FYP/data/test/images
# Out:
# 2023-11-25 11:29:51.584617: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-25 11:29:51.584673: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-25 11:29:51.584707: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-25 11:29:52.619585: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/drive/MyDrive/project/FYP/runs/detect/predict/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/drive/MyDrive/project/FYP/runs/detect/train4/results.csv')

# %%
data
# Out:
#                       epoch           train/box_loss           train/cls_loss  \
# 0                         0                  2.13470                  2.63390
# 1                         1                  1.85910                  2.56400
# 2                         2                  1.65000                  2.24950
# 3                         3                  1.51800                  1.98720
# 4                         4                  1.32630                  1.82850
# ..                      ...                      ...                      ...
# 95                       95                  0.33371                  0.66480
# 96                       96                  0.37682                  0.77770
# 97                       97                  0.34122                  0.60569
# 98                       98                  0.37458                  0.56712
# 99                       99                  0.36424                  0.63115
#
# ...
